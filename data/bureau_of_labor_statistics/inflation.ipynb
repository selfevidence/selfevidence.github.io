# %%
from datetime import datetime as dt
import pandas as pd
from api_bls import get_bls_data

# %%
current_year= int(dt.now().strftime("%Y"))
years = list(range(1979, current_year + 1))

base_series_id = "CUUR" # CPI, monthly, not seasonally adjusted

regions = {
    "0000": "National",
    "0100": "Northeast",
    "0200": "Midwest",
    "0300": "South",
    "0400": "West",
}

items = {
    "SA0": "All items",
    "SA0L1E": "Core CPI (excludes food & energy)",
    "SAA": "Apparel",
    "SAE": "Education and communication",
    "SAF": "Food and beverages",
    "SAG": "Other goods and services",
    "SAH": "Housing",
    "SAM": "Medical care",
    "SAR": "Recreation",
    "SAT": "Transportation",
}

series_ids = [base_series_id + region + item for region in regions for item in items]

# %%
df = get_bls_data(
    series_ids = series_ids,
    years = years
)

df.head()
# Out:
# {'status': 'REQUEST_SUCCEEDED', 'responseTime': 1744, 'message': ['No Data Available for Series CUUR0000SAE Year: 1979', 'No Data Available for Series CUUR0000SAE Year: 1980', 'No Data Available for Series CUUR0000SAE Year: 1981', 'No Data Available for Series CUUR0000SAE Year: 1982', 'No Data Available for Series CUUR0000SAE Year: 1983', 'No Data Available for Series CUUR0000SAE Year: 1984', 'No Data Available for Series CUUR0000SAE Year: 1985', 'No Data Available for Series CUUR0000SAE Year: 1986', 'No Data Available for Series CUUR0000SAE Year: 1987', 'No Data Available for Series CUUR0000SAE Year: 1988', 'No Data Available for Series CUUR0000SAE Year: 1989', 'No Data Available for Series CUUR0000SAE Year: 1990', 'No Data Available for Series CUUR0000SAE Year: 1991', 'No Data Available for Series CUUR0000SAE Year: 1992', 'No Data Available for Series CUUR0000SAR Year: 1979', 'No Data Available for Series CUUR0000SAR Year: 1980', 'No Data Available for Series CUUR0000SAR Year: 1981
# ...

# %%
df['region'] = df['series id'].str[4:8].apply(lambda x: regions[x])
df['item'] = df['series id'].str[8:].apply(lambda x: items[x])
df['date'] = df['year'].astype(str) + '-' + df['period'].str[1:]
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#      series id  year period  value  footnotes    region       item       date
# 0  CUUR0000SA0  1998    M12  163.9        NaN  National  All items 1998-12-01
# 1  CUUR0000SA0  1998    M11  164.0        NaN  National  All items 1998-11-01
# 2  CUUR0000SA0  1998    M10  164.0        NaN  National  All items 1998-10-01
# 3  CUUR0000SA0  1998    M09  163.6        NaN  National  All items 1998-09-01
# 4  CUUR0000SA0  1998    M08  163.4        NaN  National  All items 1998-08-01

# %%
df.dtypes

# %%
df.describe()

# %%
df.to_csv('inflation_data.csv', index=False)
