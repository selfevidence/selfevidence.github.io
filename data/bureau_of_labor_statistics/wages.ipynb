# %% [markdown]
# # Pulling Inflation Data from BLS

# %%
from datetime import datetime as dt
import pandas as pd
from api_bls import get_bls_data

hit_api = False

# %%
current_year= int(dt.now().strftime("%Y"))
years = list(range(1979, current_year + 1))

# series_ids obtained from: https://data.bls.gov/PDQWeb/le

series_ids = {
    
    # First Decile
    'LEU0252911200': {
        'description': '(unadj)- Usual weekly earnings (first decile), Employed full time, Wage and salary workers',
        'percentile': 10,
        'race': 'All'
    },
    'LEU0252912400': {
        'description': '(unadj)- Usual weekly earnings (first decile), Employed full time, Wage and salary workers, White',
        'percentile': 10,
        'race': 'White'
    },
    'LEU0252914800': {
        'description': '(unadj)- Usual weekly earnings (first decile), Employed full time, Wage and salary workers, Hispanic / Latino',
        'percentile': 10,
        'race': 'Hispanic / Latino'
    },
    'LEU0252913600': {
        'description': '(unadj)- Usual weekly earnings (first decile), Employed full time, Wage and salary workers, Black',
        'percentile': 10,
        'race': 'Black'
    },
    'LEU0254871400': {
        'description': '(unadj)- Usual weekly earnings (first decile), Employed full time, Wage and salary workers, Asian',
        'percentile': 10,
        'race': 'Asian'
    },

    # First Quartile
    'LEU0252911300': {
        'description': '(unadj)- Usual weekly earnings (first quartile), Employed full time, Wage and salary workers',
        'percentile': 25,
        'race': 'All'
    },
    'LEU0252912500': {
        'description': '(unadj)- Usual weekly earnings (first quartile), Employed full time, Wage and salary workers, White',
        'percentile': 25,
        'race': 'White'
    },
    'LEU0252914900': {
        'description': '(unadj)- Usual weekly earnings (first quartile), Employed full time, Wage and salary workers, Hispanic / Latino',
        'percentile': 25,
        'race': 'Hispanic / Latino'
    },
    'LEU0252913700': {
        'description': '(unadj)- Usual weekly earnings (first quartile), Employed full time, Wage and salary workers, Black',
        'percentile': 25,
        'race': 'Black'
    },
    'LEU0254871700': {
        'description': '(unadj)- Usual weekly earnings (first quartile), Employed full time, Wage and salary workers, Asian',
        'percentile': 25,
        'race': 'Asian'
    },

    # Second Quartile
    'LEU0252881500': {
        'description': '(unadj)- Usual weekly earnings (second quartile), Employed full time, Wage and salary workers',
        'percentile': 50,
        'race': 'All'
    },
    'LEU0252883600': {
        'description': '(unadj)- Median usual weekly earnings (second quartile), Employed full time, Wage and salary workers, White',
        'percentile': 50,
        'race': 'White'
    },
    'LEU0252885400': {
        'description': '(unadj)- Median usual weekly earnings (second quartile), Employed full time, Wage and salary workers, Hispanic / Latino',
        'percentile': 50,
        'race': 'Hispanic / Latino'
    },
    'LEU0252884500': {
        'description': '(unadj)- Median usual weekly earnings (second quartile), Employed full time, Wage and salary workers, Black',
        'percentile': 50,
        'race': 'Black'
    },
    'LEU0254468400': {
        'description': '(unadj)- Median usual weekly earnings (second quartile), Employed full time, Wage and salary workers, Asian',
        'percentile': 50,
        'race': 'Asian'
    },

    # Third Quartile
    'LEU0252911400': {
        'description': '(unadj)- Usual weekly earnings (third quartile), Employed full time, Wage and salary workers',
        'percentile': 75,
        'race': 'All'
    },
    'LEU0252912600': {
        'description': '(unadj)- Usual weekly earnings (third quartile), Employed full time, Wage and salary workers, White',
        'percentile': 75,
        'race': 'White'
    },
    'LEU0252915000': {
        'description': '(unadj)- Usual weekly earnings (third quartile), Employed full time, Wage and salary workers, Hispanic / Latino',
        'percentile': 75,
        'race': 'Hispanic / Latino'
    },
    'LEU0252913800': {
        'description': '(unadj)- Usual weekly earnings (third quartile), Employed full time, Wage and salary workers, Black',
        'percentile': 75,
        'race': 'Black'
    },
    'LEU0254872000': {
        'description': '(unadj)- Usual weekly earnings (third quartile), Employed full time, Wage and salary workers, Asian',
        'percentile': 75,
        'race': 'Asian'
    },

    # Ninth Decile
    'LEU0252911500': {
        'description': '(unadj)- Usual weekly earnings (ninth decile), Employed full time, Wage and salary workers',
        'percentile': 90,
        'race': 'All'
    },
    'LEU0252912700': {
        'description': '(unadj)- Usual weekly earnings (ninth decile), Employed full time, Wage and salary workers, White',
        'percentile': 90,
        'race': 'White'
    },
    'LEU0252915100': {
        'description': '(unadj)- Usual weekly earnings (ninth decile), Employed full time, Wage and salary workers, Hispanic / Latino',
        'percentile': 90,
        'race': 'Hispanic / Latino'
    },
    'LEU0252913900': {
        'description': '(unadj)- Usual weekly earnings (ninth decile), Employed full time, Wage and salary workers, Black',
        'percentile': 90,
        'race': 'Black'
    },
    'LEU0254872300': {
        'description': '(unadj)- Usual weekly earnings (ninth decile), Employed full time, Wage and salary workers, Asian',
        'percentile': 90,
        'race': 'Asian'
    },

}

# %%
if hit_api:
    df = get_bls_data(
        series_ids = list(series_ids.keys()),
        years = years,
        print_output = True
    )
else:
    df = pd.read_csv('output/wage_data.csv')
    
df.head()
# Out:
# {'status': 'REQUEST_SUCCEEDED', 'responseTime': 1204, 'message': ['No Data Available for Series LEU0252911200 Year: 1979', 'No Data Available for Series LEU0252911200 Year: 1980', 'No Data Available for Series LEU0252911200 Year: 1981', 'No Data Available for Series LEU0252911200 Year: 1982', 'No Data Available for Series LEU0252911200 Year: 1983', 'No Data Available for Series LEU0252911200 Year: 1984', 'No Data Available for Series LEU0252911200 Year: 1985', 'No Data Available for Series LEU0252911200 Year: 1986', 'No Data Available for Series LEU0252911200 Year: 1987', 'No Data Available for Series LEU0252911200 Year: 1988', 'No Data Available for Series LEU0252911200 Year: 1989', 'No Data Available for Series LEU0252911200 Year: 1990', 'No Data Available for Series LEU0252911200 Year: 1991', 'No Data Available for Series LEU0252911200 Year: 1992', 'No Data Available for Series LEU0252911200 Year: 1993', 'No Data Available for Series LEU0252911200 Year: 1994', 'No Data Available for Series LEU0252911200 Year: 1995', 'No Data Available for Series LEU0252911200 Year: 1996', 'No Data Available for Series LEU0252911200 Year: 1997', 'No Data Available for Series LEU0252911200 Year: 1998', 'No Data Available for Series LEU0252912400 Year: 1979', 'No Data Available for Series LEU0252912400 Year: 1980', 'No Data Available for Series LEU0252912400 Year: 1981', 'No Data Available for Series LEU0252912400 Year: 1982', 'No Data Available for Series LEU0252912400 Year: 1983', 'No Data Available for Series LEU0252912400 Year: 1984', 'No Data Available for Series LEU0252912400 Year: 1985', 'No Data Available for Series LEU0252912400 Year: 1986', 'No Data Available for Series LEU0252912400 Year: 1987', 'No Data Available for Series LEU0252912400 Year: 1988', 'No Data Available for Series LEU0252912400 Year: 1989', 'No Data Available for Series LEU0252912400 Year: 1990', 'No Data Available for Series LEU0252912400 Year: 1991', 'No Data Available for Series LEU0252912400 Year: 1992', 'No Data Available for Series LEU0252912400 Year: 1993', 'No Data Available for Series LEU0252912400 Year: 1994', 'No Data Available for Series LEU0252912400 Year: 1995', 'No Data Available for Series LEU0252912400 Year: 1996', 'No Data Available for Series LEU0252912400 Year: 1997', 'No Data Available for Series LEU0252912400 Year: 1998', 'No Data Available for Series LEU0252913600 Year: 1979', 'No Data Available for Series LEU0252913600 Year: 1980', 'No Data Available for Series LEU0252913600 Year: 1981', 'No Data Available for Series LEU0252913600 Year: 1982', 'No Data Available for Series LEU0252913600 Year: 1983', 'No Data Available for Series LEU0252913600 Year: 1984', 'No Data Available for Series LEU0252913600 Year: 1985', 'No Data Available for Series LEU0252913600 Year: 1986', 'No Data Available for Series LEU0252913600 Year: 1987', 'No Data Available for Series LEU0252913600 Year: 1988', 'No Data Available for Series LEU0252913600 Year: 1989', 'No Data Available for Series LEU0252913600 Year: 1990', 'No Data Available for Series LEU0252913600 Year: 1991', 'No Data Available for Series LEU0252913600 Year: 1992', 'No Data Available for Series LEU0252913600 Year: 1993', 'No Data Available for Series LEU0252913600 Year: 1994', 'No Data Available for Series LEU0252913600 Year: 1995', 'No Data Available for Series LEU0252913600 Year: 1996', 'No Data Available for Series LEU0252913600 Year: 1997', 'No Data Available for Series LEU0252913600 Year: 1998', 'No Data Available for Series LEU0254871400 Year: 1979', 'No Data Available for Series LEU0254871400 Year: 1980', 'No Data Available for Series LEU0254871400 Year: 1981', 'No Data Available for Series LEU0254871400 Year: 1982', 'No Data Available for Series LEU0254871400 Year: 1983', 'No Data Available for Series LEU0254871400 Year: 1984', 'No Data Available for Series LEU0254871400 Year: 1985', 'No Data Available for Series LEU0254871400 Year: 1986', 'No Data Available for Series LEU0254871400 Year: 1987', ' ...
# {'status': 'REQUEST_SUCCEEDED', 'responseTime': 1125, 'message': ['No Data Available for Series LEU0252911200 Year: 1999', 'No Data Available for Series LEU0252912400 Year: 1999', 'No Data Available for Series LEU0252913600 Year: 1999', 'No Data Available for Series LEU0254871400 Year: 1999', 'No Data Available for Series LEU0252911300 Year: 1999', 'No Data Available for Series LEU0252883600 Year: 1999', 'No Data Available for Series LEU0252885400 Year: 1999', 'No Data Available for Series LEU0252884500 Year: 1999', 'No Data Available for Series LEU0254468400 Year: 1999', 'No Data Available for Series LEU0252911400 Year: 1999', 'No Data Available for Series LEU0252911500 Year: 1999', 'No Data Available for Series LEU0252912500 Year: 1999', 'No Data Available for Series LEU0252912600 Year: 1999', 'No Data Available for Series LEU0252912700 Year: 1999', 'No Data Available for Series LEU0252913700 Year: 1999', 'No Data Available for Series LEU0252913800 Year: 1999', 'No Data Available for Series LEU0252913900 Year: 1999', 'No Data Available for Series LEU0252914800 Year: 1999', 'No Data Available for Series LEU0252914900 Year: 1999', 'No Data Available for Series LEU0252915000 Year: 1999', 'No Data Available for Series LEU0252915100 Year: 1999', 'No Data Available for Series LEU0254871700 Year: 1999', 'No Data Available for Series LEU0254872000 Year: 1999', 'No Data Available for Series LEU0254872300 Year: 1999'], 'Results': {'series': [{'seriesID': 'LEU0252911200', 'data': [{'year': '2018', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '444', 'footnotes': [{}]}, {'year': '2018', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '431', 'footnotes': [{}]}, {'year': '2018', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '426', 'footnotes': [{}]}, {'year': '2018', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '423', 'footnotes': [{}]}, {'year': '2017', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '417', 'footnotes': [{}]}, {'year': '2017', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '413', 'footnotes': [{}]}, {'year': '2017', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '410', 'footnotes': [{}]}, {'year': '2017', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '407', 'footnotes': [{}]}, {'year': '2016', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '404', 'footnotes': [{}]}, {'year': '2016', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '395', 'footnotes': [{}]}, {'year': '2016', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '395', 'footnotes': [{}]}, {'year': '2016', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '393', 'footnotes': [{}]}, {'year': '2015', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '392', 'footnotes': [{}]}, {'year': '2015', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '384', 'footnotes': [{}]}, {'year': '2015', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '384', 'footnotes': [{}]}, {'year': '2015', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '381', 'footnotes': [{}]}, {'year': '2014', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '378', 'footnotes': [{}]}, {'year': '2014', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '381', 'footnotes': [{}]}, {'year': '2014', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '377', 'footnotes': [{}]}, {'year': '2014', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '378', 'footnotes': [{}]}, {'year': '2013', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '376', 'footnotes': [{}]}, {'year': '2013', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '370', 'footnotes': [{}]}, {'year': '2013', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '374', 'footnotes': [{}]}, {'year': '2013', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '368', 'footnotes': [{}]}, {'year': '2012', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '362', 'footnotes': [{}]}, {'year': '2012', 'period': ' ...
# {'status': 'REQUEST_SUCCEEDED', 'responseTime': 424, 'message': [], 'Results': {'series': [{'seriesID': 'LEU0252911200', 'data': [{'year': '2025', 'period': 'Q02', 'periodName': '2nd Quarter', 'latest': 'true', 'value': '615', 'footnotes': [{}]}, {'year': '2025', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '619', 'footnotes': [{}]}, {'year': '2024', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '611', 'footnotes': [{}]}, {'year': '2024', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '607', 'footnotes': [{}]}, {'year': '2024', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '596', 'footnotes': [{}]}, {'year': '2024', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '594', 'footnotes': [{}]}, {'year': '2023', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '590', 'footnotes': [{}]}, {'year': '2023', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '587', 'footnotes': [{}]}, {'year': '2023', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '581', 'footnotes': [{}]}, {'year': '2023', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '574', 'footnotes': [{}]}, {'year': '2022', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '571', 'footnotes': [{}]}, {'year': '2022', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '560', 'footnotes': [{}]}, {'year': '2022', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '547', 'footnotes': [{}]}, {'year': '2022', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '531', 'footnotes': [{}]}, {'year': '2021', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '520', 'footnotes': [{}]}, {'year': '2021', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '510', 'footnotes': [{}]}, {'year': '2021', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '502', 'footnotes': [{}]}, {'year': '2021', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '486', 'footnotes': [{}]}, {'year': '2020', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '488', 'footnotes': [{}]}, {'year': '2020', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '490', 'footnotes': [{}]}, {'year': '2020', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '496', 'footnotes': [{}]}, {'year': '2020', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '468', 'footnotes': [{}]}, {'year': '2019', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '467', 'footnotes': [{}]}, {'year': '2019', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '461', 'footnotes': [{}]}, {'year': '2019', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '454', 'footnotes': [{}]}, {'year': '2019', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '442', 'footnotes': [{}]}]}, {'seriesID': 'LEU0252912400', 'data': [{'year': '2025', 'period': 'Q02', 'periodName': '2nd Quarter', 'latest': 'true', 'value': '627', 'footnotes': [{}]}, {'year': '2025', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '626', 'footnotes': [{}]}, {'year': '2024', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '621', 'footnotes': [{}]}, {'year': '2024', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '616', 'footnotes': [{}]}, {'year': '2024', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '607', 'footnotes': [{}]}, {'year': '2024', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '603', 'footnotes': [{}]}, {'year': '2023', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '595', 'footnotes': [{}]}, {'year': '2023', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '597', 'footnotes': [{}]}, {'year': '2023', 'period': 'Q02', 'periodName': '2nd Quarter', 'value': '589', 'footnotes': [{}]}, {'year': '2023', 'period': 'Q01', 'periodName': '1st Quarter', 'value': '582', 'footnotes': [{}]}, {'year': '2022', 'period': 'Q04', 'periodName': '4th Quarter', 'value': '580', 'footnotes': [{}]}, {'year': '2022', 'period': 'Q03', 'periodName': '3rd Quarter', 'value': '574', 'footnotes': [{}]}, {'year': '2022', 'period': 'Q02 ...
#        series id  year period value
# 0  LEU0252881500  1998    Q04   541
# 1  LEU0252881500  1998    Q03   520
# 2  LEU0252881500  1998    Q02   515
# 3  LEU0252881500  1998    Q01   521
# 4  LEU0252881500  1997    Q04   511

# %%
df['data_type'] = 'CPS Weekly Nominal Earnings'
df['description'] = df['series id'].apply(lambda x: series_ids[x]['description'])
df['percentile'] = df['series id'].apply(lambda x: series_ids[x]['percentile'])
df['race'] = df['series id'].apply(lambda x: series_ids[x]['race'])

df['year'] = df['year'].astype(int)
df['value'] = df['value'].astype(float)

df.head()
# Out:
#        series id  year period  value                    data_type  \
# 0  LEU0252881500  1998    Q04  541.0  CPS Weekly Nominal Earnings
# 1  LEU0252881500  1998    Q03  520.0  CPS Weekly Nominal Earnings
# 2  LEU0252881500  1998    Q02  515.0  CPS Weekly Nominal Earnings
# 3  LEU0252881500  1998    Q01  521.0  CPS Weekly Nominal Earnings
# 4  LEU0252881500  1997    Q04  511.0  CPS Weekly Nominal Earnings
#
#                                          description  percentile race
# 0  (unadj)- Usual weekly earnings (second quartil...          50  All
# 1  (unadj)- Usual weekly earnings (second quartil...          50  All
# 2  (unadj)- Usual weekly earnings (second quartil...          50  All
# 3  (unadj)- Usual weekly earnings (second quartil...          50  All
# 4  (unadj)- Usual weekly earnings (second quartil...          50  All

# %%
df.dtypes
# Out:
# series id       object
# year             int64
# period          object
# value          float64
# data_type       object
# description     object
# percentile       int64
# race            object
# dtype: object

# %%
df.describe()
# Out:
#               year        value   percentile
# count  2634.000000  2634.000000  2634.000000
# mean   2011.513288   922.373576    50.000000
# std       8.389992   618.405039    29.358892
# min    1979.000000   234.000000    10.000000
# 25%    2005.000000   448.000000    25.000000
# 50%    2012.000000   713.000000    50.000000
# 75%    2018.000000  1245.000000    75.000000
# max    2025.000000  3867.000000    90.000000

# %%
df.to_csv('output/wage_data.csv', index=False)
