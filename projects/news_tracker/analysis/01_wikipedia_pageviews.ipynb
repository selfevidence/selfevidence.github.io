# %% [markdown]
# # Wikipedia Pageviews — Data Pull
#
# Source: **Wikimedia REST API** (no authentication needed)
# Coverage: daily top 100 articles, 2015-07-01+
#
# | Column | Type | Description |
# |--------|------|-------------|
# | date | date | Day of measurement |
# | rank | int | Rank within the daily top 100 (1 = most viewed) |
# | article | str | Wikipedia article title |
# | views | int | Pageview count for that day |
#
# **Why Wikipedia Pageviews?** Complements the Current Events scrape:
# - Current Events = what Wikipedia *editors* flagged as notable
# - Pageviews = what readers *actually looked up* each day
#
# The gap between the two reveals topics with massive public interest that
# Wikipedia's editorial process overlooked or de-emphasised.

# %% [markdown]
# ## 1. Setup

# %%
from _notebook_setup import *

hit_api = True
save_output = True

PAGEVIEWS_CSV = RAW_DATA_DIR / '01_wikipedia_pageviews.csv'

# Date range for initial backfill — adjust as needed
START_DATE = date(2016, 1, 1)
END_DATE = date.today() - timedelta(days=1)  # yesterday (today not yet complete)

# %% [markdown]
# ## 2. Fetch
#
# `backfill()` skips dates already saved — safe to interrupt and re-run.
# First run from 2024-01-01 → yesterday is ~770 API calls (~7 minutes at 0.5s delay).

# %%
if hit_api:
    df_pageviews = wiki_pageviews.backfill(
        start_date=START_DATE,
        end_date=END_DATE,
        save_path=PAGEVIEWS_CSV,
    )
else:
    print("hit_api = False — loading from local cache.")
    df_pageviews = pd.read_csv(PAGEVIEWS_CSV)
    df_pageviews['date'] = pd.to_datetime(df_pageviews['date'])
# Out:
#   Fetching 1833 days (2016-01-17 → 2026-02-22) ...
#   Warning: failed to fetch 2016-01-17: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#   Warning: failed to fetch 2021-04-15: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2021/04/15
#     100/1833 days fetched ...
#     200/1833 days fetched ...
#   Warning: failed to fetch 2021-09-14: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2021/09/14
#     300/1833 days fetched ...
#     400/1833 days fetched ...
#   Warning: failed to fetch 2022-04-07: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2022/04/07
#     500/1833 days fetched ...
#     600/1833 days fetched ...
#   Warning: failed to fetch 2022-10-15: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2022/10/15
#     700/1833 days fetched ...
#   Warning: failed to fetch 2023-02-09: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2023/02/09
#     800/1833 days fetched ...
#   Warning: failed to fetch 2023-05-09: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2023/05/09
#     900/1833 days fetched ...
#   Warning: failed to fetch 2023-10-29: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2023/10/29
#   Warning: failed to fetch 2023-11-12: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2023/11/12
#     1000/1833 days fetched ...
#     1100/1833 days fetched ...
#   Warning: failed to fetch 2024-04-17: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2024/04/17
#   Warning: failed to fetch 2024-04-29: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2024/04/29
#     1200/1833 days fetched ...
#   Warning: failed to fetch 2024-07-02: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2024/07/02
#   Warning: failed to fetch 2024-08-22: 404 Client Error: Not Found for url: https://wikimedia.org/api/rest_v1/metrics/pageviews/top/en.wikipedia/all-access/2024/08/22
#     1300/1833 days fetched ...
#   Warning: failed to fetch 2024-09-11: HTTPSConnectionPool(host='wikimedia.org', port=443): Read timed out. (read timeout=30)
#     1400/1833 days fetched ...
#     1500/1833 days fetched ...
#     1600/1833 days fetched ...
#     1700/1833 days fetched ...
#     1800/1833 days fetched ...
#   Done. Saved to /Users/annebode/dev/selfevidence.github.io/projects/news_tracker/output/raw_data/01_wikipedia_pageviews.csv
#   Loaded 369,200 rows — 3692 days

# %% [markdown]
# ## 3. Inspect

# %%
print(f"Shape: {df_pageviews.shape}")
print(f"Date range: {df_pageviews['date'].min().date()} → {df_pageviews['date'].max().date()}")
df_pageviews.head(10)
# Out:
# Shape: (369200, 4)
# Date range: 2016-01-01 → 2026-02-22
#         date  rank                                        article     views
# 0 2016-01-01     1                                      Main_Page  16226325
# 1 2016-01-01     2  List_of_stock_market_crashes_and_bear_markets   1876491
# 2 2016-01-01     3                                 Special:Search   1740903
# 3 2016-01-01     4                                   Natalie_Cole    609871
# 4 2016-01-01     5                                   Special:Book    441228
# 5 2016-01-01     6                   Star_Wars:_The_Force_Awakens    353499
# 6 2016-01-01     7                                    Bobby_Leach    301290
# 7 2016-01-01     8                                   Wayne_Rogers    231465
# 8 2016-01-01     9                                      Star_Wars    211832
# 9 2016-01-01    10                                  Nat_King_Cole    199732

# %% [markdown]
# ## 4. Clean

# %%
consistent = (
    df_pageviews.groupby('article')
    .agg(
        days_in_top100=('date', 'nunique'),
        total_views=('views', 'sum'),
        avg_rank=('rank', 'mean'),
        first_seen=('date', 'min'),
        last_seen=('date', 'max'),
    )
    .sort_values('days_in_top100', ascending=False)
    .reset_index()
)
consistent['avg_rank'] = consistent['avg_rank'].round(1)

print("Most consistently popular articles (most days in top 100):")
display(consistent.head(30))
# Out:
# Most consistently popular articles (most days in top 100):
#                                     article  days_in_top100  total_views  \
# 0                                 Main_Page            3692  39103916387
# 1                            Special:Search            3692   5933784721
# 2                     Portal:Current_events            3143    159867726
# 3                             United_States            2768    126357949
# 4                              Donald_Trump            2374    251609039
# 5                                   YouTube            2246    203939272
# 6                                 Cleopatra            1883    238981171
# 7               Wikipedia:Featured_pictures            1774    438627141
# 8                                 Elon_Musk            1567    121674132
# 9                              Elizabeth_II            1390    130907988
# 10                        Special:Watchlist            1294     95516278
# 11                        Cristiano_Ronaldo            1215     82544923
# 12                                 XHamster            1206    250277837
# 13                                     XXXX            1153     66394848
# 14                    Special:CreateAccount            1148    172508627
# 15                                    Bible            1080    130895863
# 16                                  ChatGPT            1014    115586154
# 17                                Wikipedia            1011     92179915
# 18                              Ansel_Adams             944     45331007
# 19                       Special:MobileMenu             941     44475793
# 20                                 Facebook             941     62163944
# 21                        XXX_(film_series)             884     62636289
# 22                             Special:Book             872    174813879
# 23                                Instagram             841     53293961
# 24  List_of_Marvel_Cinematic_Universe_films             813     51020950
# 25                         Microsoft_Office             758     54920542
# 26                              Darth_Vader             755     69495577
# 27                          XXX_(2002_film)             748     51480683
# 28                                    India             745     30858643
# 29                              F5_Networks             715     37501557
#
#     avg_rank first_seen  last_seen
# 0        1.0 2016-01-01 2026-02-22
# 1        2.1 2016-01-01 2026-02-22
# 2       63.9 2016-01-04 2026-02-21
# 3       72.7 2016-01-04 2026-02-12
# 4       49.8 2016-01-01 2026-02-21
# 5       45.8 2016-04-30 2026-02-21
# 6       25.7 2016-08-13 2025-12-30
# 7       15.5 2021-03-22 2026-02-22
# 8       53.5 2016-03-22 2026-02-05
# 9       56.0 2016-03-27 2026-02-20
# 10      35.2 2016-01-01 2019-07-22
# 11      61.2 2016-01-12 2026-02-05
# 12      11.1 2016-01-08 2024-01-10
# 13      57.6 2016-04-09 2024-12-21
# 14      19.6 2016-06-10 2026-02-15
# 15      25.3 2019-03-06 2022-11-16
# 16      33.9 2022-12-07 2026-02-22
# 17      61.5 2016-01-15 2026-01-15
# 18      72.6 2021-09-23 2026-02-21
# 19      65.7 2016-01-01 2019-07-18
# 20      62.4 2016-01-02 2024-05-16
# 21      54.7 2017-01-14 2026-02-19
# 22      24.5 2016-01-01 2019-07-17
# 23      62.4 2019-12-18 2026-02-22
# 24      60.2 2016-04-13 2025-08-04
# 25      44.2 2019-11-09 2024-11-21
# 26      26.7 2016-01-02 2020-11-29
# 27      50.5 2016-07-21 2026-02-19
# 28      82.7 2016-01-07 2025-08-15
# 29      59.5 2018-08-01 2022-07-25

# %%
df_pageviews_clean.isna().sum()
# Out:
# date       0
# rank       0
# article    6
# views      0
# dtype: int64

# %%
df_pageviews_clean = df_pageviews.copy(deep=True)

df_pageviews_clean.dropna(inplace=True)

generically_popular = consistent['article'].tolist()[:100]
df_pageviews_clean = df_pageviews_clean[~df_pageviews_clean['article'].isin(generically_popular)]

others_to_remove = ['404.php', 'Pornhub', 'Web_scraping']
df_pageviews_clean = df_pageviews_clean[~df_pageviews_clean['article'].isin(others_to_remove)]

# explicit content searches
df_pageviews_clean = df_pageviews_clean[~df_pageviews_clean['article'].str.contains('XXX')]

print(f"Shape: {df_pageviews_clean.shape}")
print(f"Rows Removed: {df_pageviews.shape[0] - df_pageviews_clean.shape[0]}")
df_pageviews_clean.head(10)
# Out:
# Shape: (298670, 4)
# Rows Removed: 70530
#          date  rank                                        article    views
# 1  2016-01-01     2  List_of_stock_market_crashes_and_bear_markets  1876491
# 3  2016-01-01     4                                   Natalie_Cole   609871
# 5  2016-01-01     6                   Star_Wars:_The_Force_Awakens   353499
# 6  2016-01-01     7                                    Bobby_Leach   301290
# 7  2016-01-01     8                                   Wayne_Rogers   231465
# 8  2016-01-01     9                                      Star_Wars   211832
# 9  2016-01-01    10                                  Nat_King_Cole   199732
# 10 2016-01-01    11                                 Auld_Lang_Syne   177494
# 11 2016-01-01    12                                 Jenny_McCarthy   160004
# 12 2016-01-01    13                         Antarctic_Snow_Cruiser   159010

# %% [markdown]
# ## 5. Explore

# %% [markdown]
# ### Top articles by total views

# %%
top_total = (
    df_pageviews_clean.groupby('article')['views']
    .sum()
    .sort_values(ascending=False)
    .reset_index()
    .rename(columns={'views': 'total_views'})
    .head(30)
)

fig = px.bar(
    top_total,
    x='total_views',
    y='article',
    orientation='h',
    title='Top 30 Wikipedia Articles by Total Pageviews (all time)',
    labels={'total_views': 'Total Views', 'article': ''},
)
fig.update_layout(yaxis={'categoryorder': 'total ascending'})
fig.show()

# %% [markdown]
# ### Most consistently popular articles
#
# Articles that appeared in the daily top 100 on the most distinct days.

# %%
consistent = (
    df_pageviews_clean.groupby('article')
    .agg(
        days_in_top100=('date', 'nunique'),
        total_views=('views', 'sum'),
        avg_rank=('rank', 'mean'),
        first_seen=('date', 'min'),
        last_seen=('date', 'max'),
    )
    .sort_values('days_in_top100', ascending=False)
    .reset_index()
)
consistent['avg_rank'] = consistent['avg_rank'].round(1)

print("Most consistently popular articles (most days in top 100):")
display(consistent.head(30))
# Out:
# Most consistently popular articles (most days in top 100):
#                                      article  days_in_top100  total_views  \
# 0                               World_War_II             262     10709319
# 1                           Google_Translate             261     12058893
# 2                       Apple_Network_Server             260     16347035
# 3                              Melania_Trump             260     31304699
# 4                              Elvis_Presley             255     20836831
# 5                             Novak_Djokovic             255     29232338
# 6            List_of_Bollywood_films_of_2018             254     10726706
# 7                          Winston_Churchill             251     15193009
# 8   2024_United_States_presidential_election             251     28775862
# 9                   Diana,_Princess_of_Wales             250     28061072
# 10                                 Tom_Brady             248     32084725
# 11                                     Gmail             245     10289928
# 12           List_of_Bollywood_films_of_2019             245     10974286
# 13                               Andrew_Tate             243     22367171
# 14                                     QAnon             238     20905272
# 15  2020_United_States_presidential_election             237     32776417
# 16                                Tom_Cruise             236     15267074
# 17                        Oppenheimer_(film)             235     32859778
# 18      User:GoogleAnalitycsRoman/google-api             226     25732575
# 19                     J._Robert_Oppenheimer             226     31998078
# 20                            Michael_Jordan             224     21510481
# 21                                 Lady_Gaga             224     18753299
# 22                               Jason_Momoa             223     16963868
# 23                         Avengers:_Endgame             222     41365442
# 24                             O._J._Simpson             219     23051999
# 25                               Millennials             218     10689086
# 26                 File:ITVBe_logo_2014-.svg             212     29177191
# 27                             Roger_Federer             212     21541673
# 28                       2022_FIFA_World_Cup             212     46355090
# 29                                  Internet             211      9018127
#
#     avg_rank first_seen  last_seen
# 0       82.8 2016-04-11 2025-09-04
# 1       76.0 2016-10-22 2024-02-22
# 2       58.7 2019-09-24 2025-04-03
# 3       49.9 2016-01-07 2026-02-05
# 4       52.5 2016-01-08 2026-01-08
# 5       46.2 2016-01-26 2026-02-02
# 6       75.7 2018-01-19 2018-12-29
# 7       65.6 2016-02-28 2025-05-05
# 8       53.0 2022-11-16 2025-11-05
# 9       45.6 2016-04-21 2025-08-31
# 10      48.0 2016-01-16 2026-02-09
# 11      79.5 2016-11-05 2023-07-05
# 12      68.9 2019-02-22 2019-12-31
# 13      51.6 2022-06-27 2025-12-22
# 14      49.6 2018-08-01 2023-07-14
# 15      50.9 2019-02-19 2024-11-28
# 16      56.1 2016-10-21 2025-11-18
# 17      46.5 2022-07-21 2024-06-23
# 18      29.0 2016-01-02 2016-10-06
# 19      44.4 2016-03-24 2025-12-21
# 20      49.1 2016-01-25 2025-10-22
# 21      54.4 2016-01-11 2026-02-11
# 22      54.6 2016-07-24 2026-02-01
# 23      29.7 2018-12-07 2021-03-14
# 24      43.3 2016-01-27 2025-11-17
# 25      79.6 2016-04-27 2020-08-03
# 26      20.5 2017-08-31 2018-04-02
# 27      50.5 2016-01-24 2026-02-01
# 28      43.9 2018-06-13 2025-12-05
# 29      80.7 2019-03-12 2023-04-18

# %% [markdown]
# ### Daily top article over time

# %%
daily_top = (
    df_pageviews[df_pageviews['rank'] == 1]
    .sort_values('date')
    [['date', 'article', 'views']]
    .reset_index(drop=True)
)

print(f"Daily #1 article — {len(daily_top)} days")

fig = px.scatter(
    daily_top,
    x='date',
    y='views',
    hover_data=['article'],
    title='Daily #1 Wikipedia Article by Pageviews',
    labels={'views': 'Pageviews', 'date': 'Date'},
)
fig.update_traces(marker_size=4)
fig.show()

print("\nRecent daily top articles:")
display(daily_top.tail(20))
# Out:
# Daily #1 article — 3692 days
# Recent daily top articles:
#            date    article    views
# 3672 2026-02-03  Main_Page  7039712
# 3673 2026-02-04  Main_Page  6814731
# 3674 2026-02-05  Main_Page  6754706
# 3675 2026-02-06  Main_Page  6851728
# 3676 2026-02-07  Main_Page  7136168
# 3677 2026-02-08  Main_Page  7265262
# 3678 2026-02-09  Main_Page  7022665
# 3679 2026-02-10  Main_Page  6979025
# 3680 2026-02-11  Main_Page  6893519
# 3681 2026-02-12  Main_Page  6797062
# 3682 2026-02-13  Main_Page  6715959
# 3683 2026-02-14  Main_Page  6923065
# 3684 2026-02-15  Main_Page  7076451
# 3685 2026-02-16  Main_Page  7067505
# 3686 2026-02-17  Main_Page  7086003
# 3687 2026-02-18  Main_Page  7104944
# 3688 2026-02-19  Main_Page  6972939
# 3689 2026-02-20  Main_Page  6999810
# 3690 2026-02-21  Main_Page  7232125
# 3691 2026-02-22  Main_Page  7398412

# %% [markdown]
# ## 6. Gap Analysis: Popular articles NOT in Wikipedia Current Events
#
# Articles that drew massive pageviews but were absent from Wikipedia's
# Current Events editorial list — revealing what readers cared about
# that editors didn't flag as a notable news event.

# %%
df_wiki = load_data(filename='00_wikipedia_events.csv', subdir='raw_data')

if df_wiki is not None:
    wiki_blob = ' '.join(df_wiki['description'].str.lower().fillna(''))

    # Score each article by total views, then check presence in Current Events
    article_totals = (
        df_pageviews.groupby('article')['views']
        .sum()
        .sort_values(ascending=False)
        .reset_index()
        .rename(columns={'views': 'total_views'})
    )

    article_totals['in_current_events'] = article_totals['article'].apply(
        lambda a: a.lower().replace('_', ' ') in wiki_blob
    )

    gaps = article_totals[~article_totals['in_current_events']].copy()
    covered = article_totals[article_totals['in_current_events']].copy()

    print(f"Total unique articles: {len(article_totals):,}")
    print(f"In Wikipedia Current Events: {len(covered):,} ({100*len(covered)/len(article_totals):.1f}%)")
    print(f"NOT in Wikipedia Current Events: {len(gaps):,} ({100*len(gaps)/len(article_totals):.1f}%)")
    print(f"\nTop 50 high-traffic articles absent from Current Events:")
    display(gaps.head(50))
else:
    print("Wikipedia Current Events data not found.\n"
          "Run 00_wikipedia_events.ipynb first to generate 00_wikipedia_events.csv")

# %%
# Visualise the gap
if df_wiki is not None and 'gaps' in dir():
    top_gaps = gaps.head(30)

    fig = px.bar(
        top_gaps,
        x='total_views',
        y='article',
        orientation='h',
        title='Top 30 High-Traffic Wikipedia Articles NOT in Current Events',
        labels={'total_views': 'Total Pageviews', 'article': ''},
        color='total_views',
        color_continuous_scale='Blues',
    )
    fig.update_layout(yaxis={'categoryorder': 'total ascending'}, coloraxis_showscale=False)
    fig.show()
